# %% [markdown]
# ## Depth Analysis

# %%
from netCDF4 import Dataset
import numpy as np
import pandas as pd 
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reshapping Code

# %%
import xarray as xr
import numpy as np

# --- Corrected File Paths ---
PATH_CMEMS = r'V2/new_dAtA/cmems_mod_ibi_wav_my_0.027deg_static_1767883179577.nc'
PATH_GEBCO = r"V2/new_dAtA/GEBCO_08_Jan_2026_cc3cb16a4f5f/gebco_2020_n43.5_s39.0_w-13.0_e-8.5.nc"
PATH_OUTPUT_NEW_STATIC = r'V2/new_dAtA/cmems_GEBCO_resampled_new.nc'

# --- STEP 1: Inspecting the Datasets ---
try:
    print("--- 1. CMEMS Dataset Details ---")
    with xr.open_dataset(PATH_CMEMS) as ds_cmems:
        print(ds_cmems.data_vars.keys())
        print(ds_cmems.dims)

    print("\n" + "="*50 + "\n")

    print("--- 2. GEBCO Dataset Details ---")
    with xr.open_dataset(PATH_GEBCO) as ds_gebco:
        print(ds_gebco.data_vars.keys())
        print(ds_gebco.dims)

    print("\n" + "="*50 + "\n")

# --- STEP 2: Resampling and Saving ---
    # Load datasets again for processing
    ds_cmems = xr.open_dataset(PATH_CMEMS)
    ds_gebco = xr.open_dataset(PATH_GEBCO)
    
    ds_cmems['deptho'].values = np.nan_to_num(ds_cmems['deptho'].values, nan=0.0).astype(np.float32)
    
    # Standardize Coordinate Names to prevent errors
    ds_gebco = ds_gebco.rename({'lat': 'latitude', 'lon': 'longitude'})
    print("✅ GEBCO coordinates renamed for compatibility.")

    # --- MODIFICATION IS HERE ---
    # Interpolate the high-resolution data and use extrapolation to fill any gaps at the edges.
    ds_gebco_resampled = ds_gebco.interp_like(
        ds_cmems,
        method='linear',
        kwargs={'fill_value': 'extrapolate'}
    )
    print("✅ GEBCO data successfully resampled and extrapolated to match CMEMS grid.")

    # Prepare data variables
    new_depth_data = ds_gebco_resampled['elevation'].values * -1
    original_mask = ds_cmems['mask'].values

    # Create the new, combined dataset
    ds_new_static = xr.Dataset(
        data_vars={
            'deptho': (('latitude', 'longitude'), new_depth_data),
            'mask': (('latitude', 'longitude'), original_mask)
        },
        coords={
            'latitude': ds_cmems['latitude'],
            'longitude': ds_cmems['longitude']
        }
    )

    # Save the final file
    ds_new_static.to_netcdf(PATH_OUTPUT_NEW_STATIC)
    print(f"\n✅ Successfully created new static file at: {PATH_OUTPUT_NEW_STATIC}")

    # Verification
    print("\n--- Verifying Created File ---")
    with xr.open_dataset(PATH_OUTPUT_NEW_STATIC) as ds_verify:
        print(ds_verify.data_vars.keys())
        print(ds_verify.dims)

except FileNotFoundError as e:
    print(f"❌ ERROR: A file was not found. Please double-check the corrected paths.")
    print(e)
except Exception as e:
    print(f"An error occurred: {e}")


# import xarray as xr
# import numpy as np

# # --- Corrected File Paths ---
# PATH_CMEMS = r'dAtA/cmems_mod_ibi_wav_my_0.027deg_static_1756186965833.nc'
# PATH_GEBCO = r"C:\Users\user\Documents\GitHub\Wave-Prediction\dAtA\Sea_surface\gebco_2020_n40.5_s38.5_w-11.0_e-8.5.nc"
# PATH_OUTPUT_NEW_STATIC = r'dAtA/cmems_GEBCO_resampled.nc'

# # --- STEP 1: Inspecting the Datasets ---
# try:
#     print("--- 1. CMEMS Dataset Details ---")
#     with xr.open_dataset(PATH_CMEMS) as ds_cmems:
#         print(ds_cmems.data_vars.keys())
#         print(ds_cmems.dims)

#     print("\n" + "="*50 + "\n")

#     print("--- 2. GEBCO Dataset Details ---")
#     with xr.open_dataset(PATH_GEBCO) as ds_gebco:
#         print(ds_gebco.data_vars.keys())
#         print(ds_gebco.dims)

#     print("\n" + "="*50 + "\n")

# # --- STEP 2: Resampling and Saving ---
#     # Load datasets again for processing
#     ds_cmems = xr.open_dataset(PATH_CMEMS)
#     ds_gebco = xr.open_dataset(PATH_GEBCO)
    
#     ds_cmems['deptho'].values = np.nan_to_num(ds_cmems['deptho'].values, nan=0.0).astype(np.float32)
    
#     # Standardize Coordinate Names to prevent errors
#     ds_gebco = ds_gebco.rename({'lat': 'latitude', 'lon': 'longitude'})
#     print("✅ GEBCO coordinates renamed for compatibility.")

#     # --- MODIFICATION IS HERE ---
#     # Interpolate the high-resolution data and use extrapolation to fill any gaps at the edges.
#     ds_gebco_resampled = ds_gebco.interp_like(
#         ds_cmems,
#         method='linear',
#         kwargs={'fill_value': 'extrapolate'}
#     )
#     print("✅ GEBCO data successfully resampled and extrapolated to match CMEMS grid.")

#     # Prepare data variables
#     new_depth_data = ds_gebco_resampled['elevation'].values * -1
#     original_mask = ds_cmems['mask'].values

#     # Create the new, combined dataset
#     ds_new_static = xr.Dataset(
#         data_vars={
#             'deptho': (('latitude', 'longitude'), new_depth_data),
#             'mask': (('latitude', 'longitude'), original_mask)
#         },
#         coords={
#             'latitude': ds_cmems['latitude'],
#             'longitude': ds_cmems['longitude']
#         }
#     )

#     # Save the final file
#     ds_new_static.to_netcdf(PATH_OUTPUT_NEW_STATIC)
#     print(f"\n✅ Successfully created new static file at: {PATH_OUTPUT_NEW_STATIC}")

#     # Verification
#     print("\n--- Verifying Created File ---")
#     with xr.open_dataset(PATH_OUTPUT_NEW_STATIC) as ds_verify:
#         print(ds_verify.data_vars.keys())
#         print(ds_verify.dims)

# except FileNotFoundError as e:
#     print(f"❌ ERROR: A file was not found. Please double-check the corrected paths.")
#     print(e)
# except Exception as e:
#     print(f"An error occurred: {e}")
# Out:
# --- 1. CMEMS Dataset Details ---
# KeysView(Data variables:
#     deptho   (latitude, longitude) float32 105kB ...
#     mask     (latitude, longitude) float32 105kB ...)
# FrozenMappingWarningOnValuesAccess({'latitude': 162, 'longitude': 162})
#
# ...
#
# --- 2. GEBCO Dataset Details ---
# KeysView(Data variables:
#     elevation  (lat, lon) int16 2MB ...)
# FrozenMappingWarningOnValuesAccess({'lat': 1080, 'lon': 1080})
#
# ...
#
# ✅ GEBCO coordinates renamed for compatibility.
# ✅ GEBCO data successfully resampled and extrapolated to match CMEMS grid.
#
# ✅ Successfully created new static file at: V2/new_dAtA/cmems_GEBCO_resampled_new.nc
#
# --- Verifying Created File ---
# KeysView(Data variables:
#     deptho   (latitude, longitude) float64 210kB ...
#     mask     (latitude, longitude) float32 105kB ...)
# FrozenMappingWarningOnValuesAccess({'latitude': 162, 'longitude': 162})

# %%
import xarray as xr
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401
import numpy as np

# dAtA\cmems_mod_ibi_wav_my_0.027deg_static_1756186965833.nc

ds = xr.open_dataset("V2/new_dAtA/cmems_GEBCO_resampled_new.nc")  

# Extract data
lat = ds['latitude'].values
lon = ds['longitude'].values
depth = ds['deptho'].values  # Assuming shape is [lat, lon] or similar

# Make sure lat/lon are 2D meshgrids
if lat.ndim == 1 and lon.ndim == 1:
    lon_grid, lat_grid = np.meshgrid(lon, lat)
else:
    lon_grid, lat_grid = lon, lat

# Optional: Mask values (e.g., land = NaN)
# if 'mask' in ds:
#     mask = ds['mask'].values
#     depth = np.where(mask == 1, depth, np.nan)

# Create 3D plot
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')

surf = ax.plot_surface(lon_grid, lat_grid, -depth, cmap='viridis', linewidth=0, antialiased=False)

ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_zlabel('Depth (m)')
ax.set_title('3D Plot of Ocean Depth (Bathymetry)')

fig.colorbar(surf, shrink=0.5, aspect=10, label='Depth (m)')
plt.tight_layout()
plt.show()

# %%
ds['deptho'] = ds['deptho'].fillna(0.0)

# %%
ds['deptho'].isnull().sum().item()
# Out:
# 0

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import xarray as xr
import numpy as np

# 1. Define the paths to both datasets
PATH_CMEMS = r'new_dAtA/mask_deptho.nc'
PATH_GEBCO =r"new_dAtA/GEBCO_08_Jan_2026_cc3cb16a4f5f/gebco_2020_n43.5_s39.0_w-13.0_e-8.5.nc"

try:
    # 2. Load both datasets
    ds_cmems = xr.open_dataset(PATH_CMEMS)
    ds_gebco = xr.open_dataset(PATH_GEBCO)

    print("✅ Datasets loaded successfully.")

    # 3. Resample (interpolate) the GEBCO data to match the CMEMS grid.
    # This is the "masking" step.
    ds_gebco_resampled = ds_gebco.interp_like(ds_cmems)
    print("✅ GEBCO data resampled to match CMEMS grid.")

    # 4. Prepare data for plotting from both sources
    
    # CMEMS data
    lat_cmems = ds_cmems['latitude'].values
    lon_cmems = ds_cmems['longitude'].values
    elev_cmems = ds_cmems['deptho'].values * -1 # Convert depth to negative elevation
    elev_cmems = np.nan_to_num(elev_cmems, nan=0.0)

    # Resampled GEBCO data
    lat_gebco = ds_gebco_resampled['lat'].values
    lon_gebco = ds_gebco_resampled['lon'].values
    elev_gebco = ds_gebco_resampled['elevation'].values # GEBCO is already elevation
    elev_gebco = np.nan_to_num(elev_gebco, nan=0.0)

    # 5. Create side-by-side plots
    fig = make_subplots(
        rows=1, cols=2,
        specs=[[{'type': 'surface'}, {'type': 'surface'}]],
        subplot_titles=('Original CMEMS Data', 'Higher-Resolution GEBCO Data')
    )
# 'viridis', 'plasma', 'inferno', 'magma', 'cividis', 'Greys', 'Blues', 'Pinkyl'
    colur = 'inferno'
    # Add CMEMS plot
    fig.add_trace(
        go.Surface(z=elev_cmems, x=lon_cmems, y=lat_cmems, colorscale= colur, showscale=False),
        row=1, col=1)

    # Add GEBCO plot
    fig.add_trace(
        go.Surface(z=elev_gebco, x=lon_gebco, y=lat_gebco, colorscale=colur, showscale=False),
        row=1, col=2)

    fig.update_layout(
        title_text='Seafloor Bathymetry Comparison',
        height=800,
        width=1600
    )
    
    fig.show()

except FileNotFoundError as e:
    print(f"❌ ERROR: A file was not found. Please check the path.")
    print(e)
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# ✅ Datasets loaded successfully.
# ✅ GEBCO data resampled to match CMEMS grid.

# %%
import xarray as xr
import numpy as np
import plotly.graph_objects as go

file_path = "new_dAtA/cmems_GEBCO_resampled_new.nc"

try:
    ds_combined = xr.open_dataset(file_path)
except FileNotFoundError:
    print(f"Error: The file was not found at '{file_path}'")
    print("Please make sure the file path is correct.")
    exit()


lat = ds_combined['latitude'].values
lon = ds_combined['longitude'].values
depth = ds_combined['deptho'].values


lon_grid, lat_grid = np.meshgrid(lon, lat)

# if 'mask' in ds_combined:
#     mask = ds_combined['mask'].values
#     # Ensure mask has the same dimensions as depth before applying
#     if mask.shape == depth.shape:
#         depth = np.where(mask == 1, depth, np.nan)
#     else:
#         print("Warning: Mask shape does not match depth shape. Mask will not be applied.")

surface_trace = go.Surface(
    x=lon_grid,
    y=lat_grid,
    z=-depth,
    colorscale='inferno',
    connectgaps=False,  # Important for handling the land mask (NaNs)
    colorbar=dict(
        title='Depth (m)',
        len=0.75,
        x=0.85
    )
)
fig = go.Figure(data=[surface_trace])
fig.update_layout(
    height=800,
    width=1600,
    title={
        'text': 'Combined Depth',
        'y':0.9,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'
    },
    scene=dict(
        xaxis_title='Longitude',
        yaxis_title='Latitude',
        zaxis_title='Depth (m)',
        # Set aspect ratio to make the plot look more natural
        aspectratio=dict(x=1.5, y=1.5, z=0.4)
    ),
    margin=dict(l=40, r=40, b=40, t=80) # Adjust margins
)

fig.show()

# %%
ds_combined['deptho'].isnull().sum()
# Out:
# <xarray.DataArray 'deptho' ()> Size: 8B
# array(0)

# %%
d_2019 = Dataset('dAtA\Sea_surface/gebco_2019_n40.5_s38.5_w-11.0_e-8.5.nc')
d_2020 = Dataset('dAtA\Sea_surface\gebco_2020_n40.5_s38.5_w-11.0_e-8.5.nc')
d_2021 = Dataset('dAtA\Sea_surface/gebco_2021_n40.5_s38.5_w-11.0_e-8.5.nc')
d_2022 = Dataset('dAtA\Sea_surface/gebco_2022_n40.5_s38.5_w-11.0_e-8.5.nc')
d_2023 = Dataset('dAtA\Sea_surface/gebco_2023_n40.5_s38.5_w-11.0_e-8.5.nc')
d_2024 = Dataset('dAtA\Sea_surface/gebco_2024_n40.5_s38.5_w-11.0_e-8.5.nc')

# %%
d_2020.variables.keys()
# Out:
# dict_keys(['lat', 'lon', 'elevation'])

# %%
z2019 = d_2019.variables["elevation"][:]
z2020 = d_2020.variables["elevation"][:]
z2021 = d_2021.variables["elevation"][:]
z2022 = d_2022.variables["elevation"][:]
z2023 = d_2023.variables["elevation"][:]
z2024 = d_2024.variables["elevation"][:]

# %%
import numpy as np

# --- Data Preparation ---
# IMPORTANT: You must define your data arrays here first.
# This script assumes variables z2019, z2020, z2021, z2022, z2023, and z2024 exist.
# Example:
# z2019 = ... your 2019 data array ...
# z2020 = ... your 2020 data array ...
# ... and so on for all years up to z2024.


# ---- 2019 → 2020 ----
if z2019.shape != z2020.shape:
    raise ValueError("Grids do not match (2019 vs 2020)!")
diff_2019_2020 = z2020 - z2019
pct_change_2019_2020 = (diff_2019_2020 / z2019) * 100

print("=== Sea Surface Comparison (2019 → 2020) ===")
print(f"2019 Height Range: {np.nanmin(z2019):.2f} to {np.nanmax(z2019):.2f}")
print(f"2020 Height Range: {np.nanmin(z2020):.2f} to {np.nanmax(z2020):.2f}")
print(f"Minimum Change: {np.nanmin(diff_2019_2020):.2f}")
print(f"Maximum Change: {np.nanmax(diff_2019_2020):.2f}")
print(f"Average % Change: {np.nanmean(pct_change_2019_2020):.2f}%")

# ---- 2020 → 2021 ----
if z2020.shape != z2021.shape:
    raise ValueError("Grids do not match (2020 vs 2021)!")
diff_2020_2021 = z2021 - z2020
pct_change_2020_2021 = (diff_2020_2021 / z2020) * 100

print("\n=== Sea Surface Comparison (2020 → 2021) ===")
print(f"2020 Height Range: {np.nanmin(z2020):.2f} to {np.nanmax(z2020):.2f}")
print(f"2021 Height Range: {np.nanmin(z2021):.2f} to {np.nanmax(z2021):.2f}")
print(f"Minimum Change: {np.nanmin(diff_2020_2021):.2f}")
print(f"Maximum Change: {np.nanmax(diff_2020_2021):.2f}")
print(f"Average % Change: {np.nanmean(pct_change_2020_2021):.2f}%")

# ---- 2021 → 2022 ----
if z2021.shape != z2022.shape:
    raise ValueError("Grids do not match (2021 vs 2022)!")
diff_2021_2022 = z2022 - z2021
pct_change_2021_2022 = (diff_2021_2022 / z2021) * 100

print("\n=== Sea Surface Comparison (2021 → 2022) ===")
print(f"2021 Height Range: {np.nanmin(z2021):.2f} to {np.nanmax(z2021):.2f}")
print(f"2022 Height Range: {np.nanmin(z2022):.2f} to {np.nanmax(z2022):.2f}")
print(f"Minimum Change: {np.nanmin(diff_2021_2022):.2f}")
print(f"Maximum Change: {np.nanmax(diff_2021_2022):.2f}")
print(f"Average % Change: {np.nanmean(pct_change_2021_2022):.2f}%")

# ---- 2022 → 2023 ----
if z2022.shape != z2023.shape:
    raise ValueError("Grids do not match (2022 vs 2023)!")
diff_2022_2023 = z2023 - z2022
pct_change_2022_2023 = (diff_2022_2023 / z2022) * 100

print("\n=== Sea Surface Comparison (2022 → 2023) ===")
print(f"2022 Height Range: {np.nanmin(z2022):.2f} to {np.nanmax(z2022):.2f}")
print(f"2023 Height Range: {np.nanmin(z2023):.2f} to {np.nanmax(z2023):.2f}")
print(f"Minimum Change: {np.nanmin(diff_2022_2023):.2f}")
print(f"Maximum Change: {np.nanmax(diff_2022_2023):.2f}")
print(f"Average % Change: {np.nanmean(pct_change_2022_2023):.2f}%")

# ---- 2023 → 2024 ----
if z2023.shape != z2024.shape:
    raise ValueError("Grids do not match (2023 vs 2024)!")
diff_2023_2024 = z2024 - z2023
pct_change_2023_2024 = (diff_2023_2024 / z2023) * 100

print("\n=== Sea Surface Comparison (2023 → 2024) ===")
print(f"2023 Height Range: {np.nanmin(z2023):.2f} to {np.nanmax(z2023):.2f}")
print(f"2024 Height Range: {np.nanmin(z2024):.2f} to {np.nanmax(z2024):.2f}")
print(f"Minimum Change: {np.nanmin(diff_2023_2024):.2f}")
print(f"Maximum Change: {np.nanmax(diff_2023_2024):.2f}")
print(f"Average % Change: {np.nanmean(pct_change_2023_2024):.2f}%")
# Out:
# === Sea Surface Comparison (2019 → 2020) ===
# 2019 Height Range: -4995.00 to 657.00
# 2020 Height Range: -4993.00 to 662.00
# Minimum Change: -358.00
# Maximum Change: 348.00
# Average % Change: 0.61%
#
# === Sea Surface Comparison (2020 → 2021) ===
# 2020 Height Range: -4993.00 to 662.00
# 2021 Height Range: -5001.00 to 662.00
# Minimum Change: -812.00
# Maximum Change: 413.00
# Average % Change: -1.31%
#
# === Sea Surface Comparison (2021 → 2022) ===
# 2021 Height Range: -5001.00 to 662.00
# 2022 Height Range: -4996.00 to 662.00
# Minimum Change: -738.00
# Maximum Change: 431.00
# Average % Change: 0.26%
#
# === Sea Surface Comparison (2022 → 2023) ===
# 2022 Height Range: -4996.00 to 662.00
# 2023 Height Range: -4989.00 to 662.00
# Minimum Change: -456.00
# Maximum Change: 801.00
# Average % Change: -2.50%
#
# === Sea Surface Comparison (2023 → 2024) ===
# 2023 Height Range: -4989.00 to 662.00
# 2024 Height Range: -4989.00 to 662.00
# Minimum Change: -336.00
# ...

# %%
# Earth radius (meters)
R = 6371000  
depth_area = []
yrrs = [2019,2020,2021,2022,2023,2024]
dsss = [d_2019, d_2020, d_2021, d_2022, d_2023, d_2024]
for i in range(6):
    # Open file (example: 2020)
    elev = dsss[i].variables["elevation"][:]
    lat = dsss[i].variables["lat"][:]
    lon = dsss[i].variables["lon"][:]
    # ds.close()

    # Convert to radians
    lat_rad = np.deg2rad(lat)
    lon_rad = np.deg2rad(lon)

    # Compute grid spacing (assumes regular grid)
    dlat = np.abs(lat_rad[1] - lat_rad[0])
    dlon = np.abs(lon_rad[1] - lon_rad[0])

    # Compute cell area per latitude (varies with cos(lat))
    # Shape: (lat, lon)
    cell_areas = (R**2) * dlon * dlat * np.cos(lat_rad[:, None])

    # ---- Example: compute area where depth < -100 m ----
    threshold = -100
    mask = elev < threshold
    area_below_threshold = np.nansum(cell_areas * mask)
    
    depth_area.append(area_below_threshold/1e6)

    print(f"Area with depth < {threshold} m ({yrrs[i]}): {area_below_threshold/1e6:.2f} km²")
    
print(depth_area)
# Out:
# Area with depth < -100 m (2019): 30249.09 km²
# Area with depth < -100 m (2020): 30319.02 km²
# Area with depth < -100 m (2021): 30240.31 km²
# Area with depth < -100 m (2022): 30316.43 km²
# Area with depth < -100 m (2023): 30356.60 km²
# Area with depth < -100 m (2024): 30361.04 km²
# [np.float64(30249.092803111456), np.float64(30319.02419476706), np.float64(30240.30842082036), np.float64(30316.427150784355), np.float64(30356.601643900103), np.float64(30361.03850980059)]

# %%
years = [2019, 2020, 2021, 2022, 2023, 2024]

mini = [np.nanmin(z2019), np.nanmin(z2020), np.nanmin(z2021), np.nanmin(z2022), np.nanmin(z2023), np.nanmin(z2024)]
maxi = [np.nanmax(z2019), np.nanmax(z2020), np.nanmax(z2021), np.nanmax(z2022), np.nanmax(z2023), np.nanmax(z2024)]
avg_pct_change = [
    np.nanmean(pct_change_2019_2020),
    np.nanmean(pct_change_2020_2021),
    np.nanmean(pct_change_2021_2022),
    np.nanmean(pct_change_2022_2023),
    np.nanmean(pct_change_2023_2024)
]

# --- Plotting ---
fig, axs = plt.subplots(4, 1, figsize=(8, 10), sharex=True)

# Helper function to add labels beneath points
def add_labels(ax, x, y):
    """Adds formatted text labels below each point on a plot."""
    # Calculate a dynamic offset based on the y-axis range
    offset = (ax.get_ylim()[1] - ax.get_ylim()[0]) * 0.1
    for i, val in enumerate(y):
        ax.text(x[i], val - offset, f'{val:.2f}', 
                ha='center', va='top', fontsize=9, color='black', weight='bold')

# --- Min Elevation ---
axs[0].plot(years, mini, marker='o', linestyle='-', color='blue')
axs[0].set_ylabel("Min Elevation (m)")
axs[0].set_title("Minimum Elevation over Years")
axs[0].grid(True, linestyle="--", alpha=0.6)
add_labels(axs[0], years, mini)

# --- Max Elevation ---
axs[1].plot(years, maxi, marker='o', linestyle='-', color='green')
axs[1].set_ylabel("Max Elevation (m)")
axs[1].set_title("Maximum Elevation over Years")
axs[1].grid(True, linestyle="--", alpha=0.6)
add_labels(axs[1], years, maxi)

# --- Depth Area ---
axs[2].plot(years, depth_area, marker='o', linestyle='-', color='purple')
axs[2].set_ylabel("Area (km²)")
axs[2].set_title("Depth Area over Years")
axs[2].grid(True, linestyle="--", alpha=0.6)
add_labels(axs[2], years, depth_area)

# --- Avg % Change ---
change_years = years[1:]
axs[3].plot(change_years, avg_pct_change, marker='o', linestyle='-', color='red')
axs[3].set_ylabel("Avg % Change")
axs[3].set_title("Average Percentage Change Year-to-Year")
axs[3].set_xlabel("Year")
axs[3].grid(True, linestyle="--", alpha=0.6)
add_labels(axs[3], change_years, avg_pct_change)

# Set x-axis ticks to be integers for all years
plt.xticks(years)
plt.tight_layout(pad=2.0)
plt.show()

# %% [markdown]
# ## Wave Analysis

# %%
from netCDF4 import Dataset
import numpy as np

# -------------------------------------------------
# Files
# -------------------------------------------------
ds1 = Dataset(r'new_dAtA/after_xl.nc')
ds2 = Dataset(r'new_dAtA/till xl.nc')
ds3 = Dataset(r'new_dAtA/tla_taux_tauy.nc')

datasets = [ds1, ds2, ds3]

total = [
    'VMDR_SW1', 'VCMX', 'VHM0', 'VHM0_SW1', 'VHM0_SW2', 'VHM0_WW',
    'VMDR', 'VMDR_SW2', 'VMDR_WW', 'VMXL', 'VPED',
    'VSDX', 'VSDY',
    'VTM01_SW1', 'VTM01_SW2', 'VTM01_WW',
    'VTM02', 'VTM10', 'VTPK',
    'TAUX', 'TAUY', 'TLA',
    'latitude', 'longitude', 'time'
]

# -------------------------------------------------
# Output dataset
# -------------------------------------------------
out_ds = Dataset(r'new_dAtA/merged_all.nc', 'w', format='NETCDF4')

# -------------------------------------------------
# Create dimensions (from first dataset that has them)
# -------------------------------------------------
ref_ds = ds1

for dim_name, dim in ref_ds.dimensions.items():
    if dim_name == 'time':
        out_ds.createDimension(
            'time',
            size=sum(len(ds.dimensions['time']) for ds in datasets if 'time' in ds.dimensions)
        )
    else:
        out_ds.createDimension(dim_name, size=len(dim))

# -------------------------------------------------
# Helper: find dataset that contains a variable
# -------------------------------------------------
def find_ds(var_name):
    for ds in datasets:
        if var_name in ds.variables:
            return ds
    return None

# -------------------------------------------------
# Create & fill variables
# -------------------------------------------------
time_cursor = 0

for var_name in total:

    ds_ref = find_ds(var_name)
    if ds_ref is None:
        print(f"⚠️ Skipping {var_name} (not found)")
        continue

    var_ref = ds_ref.variables[var_name]

    out_var = out_ds.createVariable(
        var_name,
        var_ref.datatype,
        var_ref.dimensions,
        zlib=True
    )

    # copy attributes
    out_var.setncatts({k: var_ref.getncattr(k) for k in var_ref.ncattrs()})

    # -------------------------------------------------
    # Fill data
    # -------------------------------------------------
    if var_name == 'time':
        for ds in datasets:
            if 'time' in ds.variables:
                n = len(ds.variables['time'])
                out_var[time_cursor:time_cursor + n] = ds.variables['time'][:]
                time_cursor += n

    elif 'time' in var_ref.dimensions:
        tpos = var_ref.dimensions.index('time')
        time_cursor = 0

        for ds in datasets:
            if var_name in ds.variables:
                data = ds.variables[var_name][:]
                n = data.shape[tpos]
                out_var[time_cursor:time_cursor + n, ...] = data
                time_cursor += n

    else:
        # static variables (lat/lon)
        out_var[:] = var_ref[:]

# -------------------------------------------------
# Global attributes
# -------------------------------------------------
out_ds.setncatts({k: ds1.getncattr(k) for k in ds1.ncattrs()})

# -------------------------------------------------
# Close files
# -------------------------------------------------
for ds in datasets:
    ds.close()

out_ds.close()

print("✅ All variables merged correctly into merged_all.nc")

# %%
from netCDF4 import Dataset
all_ds = Dataset(r'new_dAtA/after_xl.nc')
all_ds1= Dataset(r'new_dAtA/till xl.nc')
ds3 = Dataset(r'new_dAtA/tla_taux_tauy.nc')
print(all_ds.variables.keys())
print(all_ds1.variables.keys())
print(ds3.variables.keys())
# Out:
# dict_keys(['VPED', 'VSDX', 'VSDY', 'VTM01_SW1', 'VTM01_SW2', 'VTM01_WW', 'VTM02', 'VTM10', 'VTPK', 'latitude', 'longitude', 'time'])
# dict_keys(['VMDR_SW1', 'VCMX', 'VHM0', 'VHM0_SW1', 'VHM0_SW2', 'VHM0_WW', 'VMDR', 'VMDR_SW2', 'VMDR_WW', 'VMXL', 'latitude', 'longitude', 'time'])
# dict_keys(['TAUX', 'TAUY', 'TLA', 'latitude', 'longitude', 'time'])

# %%
total = ['VMDR_SW1', 'VCMX', 'VHM0', 'VHM0_SW1', 'VHM0_SW2', 'VHM0_WW', 'VMDR', 'VMDR_SW2', 'VMDR_WW', 'VMXL','VPED', 'VSDX', 'VSDY', 'VTM01_SW1', 'VTM01_SW2', 'VTM01_WW', 'VTM02', 'VTM10', 'VTPK', 'TAUX', 'TAUY', 'TLA','latitude', 'longitude', 'time']
len(total)
# Out:
# 25

# %%
print(ds3['TLA'].shape)
print(all_ds['time'][0])
print(ds3['time'][0])
# Out:
# (35040, 72, 90)
# 613608.0
# 613608.0

# %%
import numpy as np

variable_data = all_ds1.variables['VCMX'][:]  # Load the data as a NumPy array

# Find the maximum value
max_value = np.max(variable_data)

# Find the index (multi-dimensional) of the maximum value
max_index = np.unravel_index(np.argmax(variable_data), variable_data.shape)
print("Max wave height",max_value)
print(max_index)
# Out:
# Max wave height 21.529999518767
# (np.int64(33690), np.int64(151), np.int64(18))

# %%
import numpy as np

# Load variable (may be a masked array)
variable_data = all_ds.variables['VCMX'][:]

# Convert masked array → normal NumPy array
if np.ma.isMaskedArray(variable_data):
    variable_data = variable_data.filled(np.nan)

# Number of top values
N = 10

# Flatten
flat_data = variable_data.reshape(-1)

# Replace NaNs so they don't interfere
flat_data_clean = np.nan_to_num(flat_data, nan=-np.inf)

# Get top N indices
top_indices_flat = np.argpartition(flat_data_clean, -N)[-N:]

# Sort indices by value (descending)
top_indices_flat = top_indices_flat[np.argsort(flat_data_clean[top_indices_flat])[::-1]]

# Convert flat indices → multi-dimensional indices
top_indices = np.unravel_index(top_indices_flat.astype(int), variable_data.shape)

print("Top 10 Maximum Values and Indices:\n")

for i in range(N):
    idx = tuple(int(dim[i]) for dim in top_indices)
    val = flat_data[top_indices_flat[i]]
    print(f"{i+1:2d}. Value = {val:.4f}, Index = {idx}")
# Out:
# Top 10 Maximum Values and Indices:
#
#  1. Value = 11.3400, Index = (33694, 71, 0)
#  2. Value = 11.3300, Index = (33694, 71, 1)
#  3. Value = 11.3200, Index = (33694, 71, 2)
#  4. Value = 11.3100, Index = (33695, 71, 5)
#  5. Value = 11.3100, Index = (33695, 71, 8)
#  6. Value = 11.3100, Index = (33695, 71, 7)
#  7. Value = 11.3100, Index = (33695, 71, 6)
#  8. Value = 11.3100, Index = (33695, 71, 10)
#  9. Value = 11.3100, Index = (33695, 71, 9)
# 10. Value = 11.3100, Index = (33695, 71, 11)

# %%
lat1=all_ds.variables["latitude"][151]
print(lat1)
print(all_ds.variables["longitude"][18])
# Out:
# 43.194973
# -12.499801

# %%
lat = all_ds1.variables['latitude'][:]
lon = all_ds1.variables['longitude'][:]
vcmx = all_ds1.variables['VCMX'][:]

Lat, Lon = np.meshgrid(lon,lat)
Lat.shape
# Out:
# (162, 162)

# %%
vcmx.shape
# Out:
# (35040, 72, 90)

# %%
from mpl_toolkits.mplot3d import axis3d
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12,10))
ax=fig.add_subplot(111, projection='3d')

# ax.view_init(roll=0, azim=0)

# lat = all_ds.variables['latitude'][:]
# lon = all_ds.variables['longitude'][:]
# vcmx = all_ds.variables['VCMX'][:]

# Lat, Lon = np.meshgrid(lat,lon)

surf = ax.plot_surface(Lat ,Lon,vcmx[33690,:,:],cmap='viridis',  edgecolor='none')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_zlabel('VCMX')
fig.colorbar(surf, shrink=0.5, aspect=5, label='VCMX')

# %% [markdown]
# ### Wave Height gif

# %%
# from netCDF4 import Dataset
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation, PillowWriter
from mpl_toolkits.mplot3d import Axes3D

# Load data
ds_height = all_ds
lat = ds_height.variables['latitude'][:]
lon = ds_height.variables['longitude'][:]
time = ds_height.variables['time'][:]
vhmo = ds_height.variables['VCMX'][:]

# Meshgrid
Lon, Lat = np.meshgrid(lon, lat)

# Choose interval to downsample frames
interval = 100
frames = list(range(0, len(time), interval))  # e.g., [0, 100, 200, ..., 20900]

# Create figure and axis
fig = plt.figure(figsize=(12, 7))
ax = fig.add_subplot(111, projection='3d')
zmin, zmax = np.nanmin(vhmo), np.nanmax(vhmo)
ax.set_zlim(zmin, zmax)
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.set_zlabel('Wave Height (m)')

# Initial surface
surf = ax.plot_surface(Lon, Lat, vhmo[0, :, :], cmap='viridis', edgecolor='none')
ax.set_title('Maximum Wave Height at time index')

# Update function
def update(frame_idx):
    global surf
    surf.remove()
    data = vhmo[frame_idx, :, :]
    surf = ax.plot_surface(Lon, Lat, data, cmap='viridis', edgecolor='none')
    ax.set_title(f'Maximum Wave Height at time index {frame_idx}')
    return surf,

# Create animation (fps=10 → ~21 sec)
interr = 10

anim = FuncAnimation(fig, update, frames=frames, interval= interr)

plt.show()

# Save as GIF
anim.save('wave_height_animation_10fps.gif', writer=PillowWriter(fps=10))

# %%
import numpy as np

vcmx = all_ds1.variables['VCMX'][:]

# Handle masked arrays
if np.ma.isMaskedArray(vcmx):
    vcmx = vcmx.filled(np.nan)

ntime, ny, nx = vcmx.shape

# How extreme? (top 1% per time)
threshold = np.nanpercentile(vcmx, 99)

# Store extreme locations
extreme_points = []

for t in range(ntime):
    mask = vcmx[t] >= threshold
    ys, xs = np.where(mask)
    for y, x in zip(ys, xs):
        extreme_points.append((y, x))

extreme_points = np.array(extreme_points)

# %%
heatmap = np.zeros((ny, nx), dtype=int)

for y, x in extreme_points:
    heatmap[y, x] += 1

heatmap_norm = heatmap / heatmap.max()

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
plt.pcolormesh(heatmap_norm, cmap='hot')
plt.colorbar(label='Relative frequency of extremes')
plt.title('Spatial clustering of extreme VCMX')
plt.xlabel('Longitude index')
plt.ylabel('Latitude index')
plt.show()
