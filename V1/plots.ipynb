# %%
from netCDF4 import Dataset

# %%
ds = Dataset("/Users/hritik/Documents/Project /Wave-Prediction copy/dAtA/cmems_mod_ibi_wav_anfc_0.027deg_PT1H-i_multi-vars_11.00W-8.53W_38.50N-40.97N_2022-12-01-2025-01-01.nc")

# %%
ds.variables.keys()
# Out:
# dict_keys(['VCMX', 'VHM0', 'VHM0_SW1', 'VHM0_SW2', 'VHM0_WW', 'VMDR', 'VMDR_SW1', 'VMDR_SW2', 'VMDR_WW', 'VMXL', 'VPED', 'VSDX', 'VSDY', 'VTM01_SW1', 'VTM01_SW2', 'VTM01_WW', 'VTM02', 'VTM10', 'VTPK', 'latitude', 'longitude', 'time'])

# %%
ds['VCMX'].shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 ds['VCMX'].max
#
# File src/netCDF4/_netCDF4.pyx:5030, in netCDF4._netCDF4.Variable.__getattr__()
#
# File src/netCDF4/_netCDF4.pyx:4752, in netCDF4._netCDF4.Variable.getncattr()
#
# File src/netCDF4/_netCDF4.pyx:1667, in netCDF4._netCDF4._get_att()
#
# File src/netCDF4/_netCDF4.pyx:2164, in netCDF4._netCDF4._ensure_nc_success()
#
# AttributeError: NetCDF: Attribute not found

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 5))
plt.plot(ds['VCMX'][:, 0, 0], label='VCMX')
plt.plot(ds['VHM0'][:, 0, 0], label='VHM0')
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Plot of VCMX and VHM0 over Time")
plt.legend()  # ← adds legend for both lines
plt.show()

# %%
plt.figure(figsize=(20, 5))
plt.plot(ds['VCMX'][:2500, 0, 0], label='VCMX')
plt.plot(ds['VHM0'][:2500, 0, 0], label='VHM0')
plt.xlabel("Index")
plt.ylabel("Value")
plt.title("Plot of VCMX and VHM0 over Time")
plt.legend()  # ← adds legend for both lines
plt.show()
